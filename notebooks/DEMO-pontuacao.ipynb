# %% [markdown]
# ## Inicialização

# %%
import importlib
import os
import sys
from glob import glob
import numpy as np
import pandas as pd
import random
from datetime import datetime as dt
caminho = os.path.abspath("../src/pylattesLXML/")
os.chdir(caminho)
dirpath = os.getcwd()
from lxml import etree
# Pacotes básicos
#show result from all calculations of the cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
#----Carregando Módulo
import pylattesLXML as lattes

# %%
files = lattes.readFolder('../../data/raw/CVs-EDITAIS-2020/*')

# %%
file = random.choice(files)
PQ = lattes.Pesquisador()
PQ.periodo = ['2020','2019','2018','2017'];
PQ.file = file
tmp = PQ.validaPath();
tmp2 = PQ.getDadosBasicos();
SUMARIO = PQ.doSumario()

# %% [markdown]
# ## Como são os currículos?

# %%
# Como são os XMLs
XML_logado = '../../data/raw/CVs/8090714349274051.xml'
XML_nao_logado = '../../data/raw/CVs/curriculo.xml'
file = XML_logado
tree = etree.parse(file)
root = tree.getroot()
CPF = root.find('DADOS-GERAIS').attrib['CPF']
NOME = root.find('DADOS-GERAIS').attrib['NOME-COMPLETO']
ID = root.attrib['NUMERO-IDENTIFICADOR']
[CPF, ID, NOME]
root.getchildren()
from lxml.etree import ParseError
from lxml.etree import ParserError
file = XML_nao_logado
tree = etree.parse(file)
root = tree.getroot()
try:
    CPF = root.find('DADOS-GERAIS').attrib['CPF']
except (ParserError, ParseError, KeyError) as error:
    CPF = ''
    print('CPF indefinido')
NOME = root.find('DADOS-GERAIS').attrib['NOME-COMPLETO']
ID = root.attrib['NUMERO-IDENTIFICADOR']
[CPF, ID, NOME]
root.getchildren()
# Out:
# ['26495179804', '8090714349274051', 'Luciano Barosi de Lemos']
# [<Element DADOS-GERAIS at 0x7f0d504467d0>,
#  <Element PRODUCAO-BIBLIOGRAFICA at 0x7f0d50446820>,
#  <Element PRODUCAO-TECNICA at 0x7f0d50446870>,
#  <Element OUTRA-PRODUCAO at 0x7f0d504468c0>,
#  <Element DADOS-COMPLEMENTARES at 0x7f0d50446910>]
# CPF indefinido
# ['', '8090714349274051', 'Luciano Barosi de Lemos']
# [<Element DADOS-GERAIS at 0x7f0d50446be0>,
#  <Element PRODUCAO-BIBLIOGRAFICA at 0x7f0d50446cd0>,
#  <Element PRODUCAO-TECNICA at 0x7f0d50446d20>,
#  <Element OUTRA-PRODUCAO at 0x7f0d50446c30>,
#  <Element DADOS-COMPLEMENTARES at 0x7f0d50446d70>]

# %% [markdown]
# # Relatório de Produção Individual

# %% [markdown]
# <center><h5> <img src="./assets/Logo-UFCG.png" width="80" > </h5>
#     <h1> UNIVERSIDADE FEDERAL DE CAMPINA GRANDE </h1>
#     <h2> PRÓ-REITORIA DE PÓS-GRADUAÇÃO </h2>
#     <h2> Coordenação de Pesquisa </h2>
#     </center>

# %% [markdown]
# <div style="color:#ff8000;" ><h2> Informações Metodológicas </h2></div>

# %% [markdown]
# - As informações foram extraídas do CV Lattes do pesquisador fornecido pelo próprio pesquisador.
# - Não foi realizada validação com o DTD do Lattes porque este está desatualizado e muitos falsos inválidos surgiram na primeira análise.
# - Todas as análises foram realizadas com Python, biblioteca LXML, que mostrou melhor performance do que as alternativas nativas.
# - Os elementos extraídos foram todos os elementos das árvores desejadas: Dados Pessoais, Formação Acadêmica, Produção Bibliográfica, Produção Técnica, Outras Produções.
# - O período considerado foi o período de quatro anos.
# - Dados de lotação foram extraídos de informações da própria UFCG, quando disponíveis.
# - Tabela Qualis é a tabela vigente.
# - Utilizou-se uma tabela de conversão entre as áreas de conhecimento e as áreas de conhecimento CAPES.
# - Pacote completo documentado será disponibilizado no GitHub.

# %% [markdown]
# <center><div style="color:blue;" ><h1> Relatório Individual de Produção Acadêmica </h1></div></center>

# %% [markdown]
# <div style="color:blue;" ><h2> Informações do Sistema </h2></div>

# %%
inicio = dt.now().strftime('%d/%m/%Y %H:%M')
print(inicio)
# !whoami
# !uname -a
# !python --version
# Out:
# 02/08/2020 16:31
# lbarosi
# Linux pergamon 4.15.0-112-generic #113-Ubuntu SMP Thu Jul 9 23:41:39 UTC 2020 x86_64 x86_64 x86_64 GNU/Linux
# Python 3.7.4

# %% [markdown]
# ### Informações das Bases de Dados

# %%
SUMARIO['DB'][0].style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_c88f6148_d4f6_11ea_9940_a5381dcde6b4" ><thead>    <tr>        <th class="col_heading level0 col0" >pathCAPES</th>        <th class="col_heading level0 col1" >pathQualis</th>        <th class="col_heading level0 col2" >pathPontos</th>        <th class="col_heading level0 col3" >pathUFCG</th>        <th class="col_heading level0 col4" >pathSAAP</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c88f6148_d4f6_11ea_9940_a5381dcde6b4row0_col0" class="data row0 col0" >../data/TABELA_EQUIVALENCIA_CNPQ_CAPES.csv</td>
#                         <td id="T_c88f6148_d4f6_11ea_9940_a5381dcde6b4row0_col1" class="data row0 col1" >../data/Qualis_2013-2016.zip</td>
#                         <td id="T_c88f6148_d4f6_11ea_9940_a5381dcde6b4row0_col2" class="data row0 col2" >../data/pontuacao.xlsx</td>
#                         <td id="T_c88f6148_d4f6_11ea_9940_a5381dcde6b4row0_col3" class="data row0 col3" >../../data/external/SERVIDORES_UFCG.xls</td>
#                         <td id="T_c88f6148_d4f6_11ea_9940_a5381dcde6b4row0_col4" class="data row0 col4" >../../data/external/SAAP_UFCG.xls</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <div style="color:blue;" ><h2> Informações do Pesquisador </h2></div>

# %% [markdown]
# #### Dados Pessoais

# %%
SUMARIO['RESUMOS'][0]
# Out:
#   DATA-ATUALIZACAO                ID          CPF  Matrícula  \
# 0         27062020  6832534027323796  51145669468    1719963
#
#                                       IES     Lotação  \
# 0  Universidade Federal de Campina Grande  UAPSI-CCBS
#
#                             NOME-COMPLETO
# 0  Maria Valquíria Nogueira do Nascimento

# %% [markdown]
# #### Dados Demográficos

# %%
SUMARIO['RESUMOS'][1]
# Out:
#                             NOME-COMPLETO DATA-NASCIMENTO NACIONALIDADE  \
# 0  Maria Valquíria Nogueira do Nascimento        15081971             B
#
#   RACA-OU-COR      SEXO UF-NASCIMENTO
# 0      Branca  FEMININO            RN

# %% [markdown]
# <div style="color:blue;" ><h2> Informações de Titulação e Formação</h2></div>

# %%
SUMARIO['RESUMOS'][2]
# Out:
#   ANO-DE-CONCLUSAO ANO-DE-INICIO  TITULACAO  \
# 0             1998          1997  GRADUACAO
# 1             1993          1989  GRADUACAO
# 2             1997          1993  GRADUACAO
# 3             2003          2001   MESTRADO
# 4             2015          2014  DOUTORADO
# 5             2016          2012  DOUTORADO
#
#                                 NOME-INSTITUICAO  \
# 0               Universidade Estadual da Paraíba
# 1  Universidade do Estado do Rio Grande do Norte
# 2               Universidade Estadual da Paraíba
# 3    Universidade Federal do Rio Grande do Norte
# 4              Universitat Autónoma de Barcelona
# 5    Universidade Federal do Rio Grande do Norte
#
#                                         NOME-AGENCIA TIPO SEQUENCIA-FORMACAO  \
# 0                                                                          7
# 1                                                                          2
# 2                                                                          4
# 3                                                                          1
# 4  Coordenação de Aperfeiçoamento de Pessoal de N...    S                  8
# 5                                                       N                  9
#
#                          NOME-CURSO STATUS-DO-CURSO
# 0            Formação em Psicologia       CONCLUIDO
# 1                            Letras       CONCLUIDO
# 2  Licenciatura Plena Em Psicologia       CONCLUIDO
# 3                        Psicologia       CONCLUIDO
# 4                        Psicologia       CONCLUIDO
# 5                        Psicologia       CONCLUIDO

# %% [markdown]
# <div style="color:blue;" ><h2> Resumo da Produção Bibliográfica </h2></div>

# %%
SUMARIO['RESUMOS'][3]
# Out:
#               PRODUCAO  NATUREZA           TIPO flag_Qualis  flag_ISSN  \
# 0     ARTIGO-PUBLICADO  COMPLETO                                  True
# 1  TRABALHO-EM-EVENTOS            INTERNACIONAL                   True
# 2  TRABALHO-EM-EVENTOS                 NACIONAL                   True
# 3  TRABALHO-EM-EVENTOS    RESUMO                                  True
#
#      PAIS  SEQUENCIA-PRODUCAO
# 0                           2
# 1                           1
# 2                           1
# 3  Brasil                   2

# %% [markdown]
# ## Resumo de Produção Técnica - Apresentações

# %%
SUMARIO['RESUMOS'][4]
# Out:
#                             PRODUCAO                       NATUREZA    PAIS  \
# 0           APRESENTACAO-DE-TRABALHO                    COMUNICACAO  Brasil
# 1           APRESENTACAO-DE-TRABALHO                          OUTRA  Brasil
# 2  CURSO-DE-CURTA-DURACAO-MINISTRADO                                 Brasil
# 3             OUTRA-PRODUCAO-TECNICA  Membro da Comissão Científica  Brasil
# 4            PROGRAMA-DE-RADIO-OU-TV                   MESA_REDONDA  Brasil
# 5              RELATORIO-DE-PESQUISA                                 Brasil
#
#    SEQUENCIA-PRODUCAO
# 0                   2
# 1                   1
# 2                   3
# 3                   1
# 4                   4
# 5                   1

# %% [markdown]
# ## Resumo de Produção Técnica - Produtos e Processos

# %%
SUMARIO['RESUMOS'][5]
# Out:
# Empty DataFrame
# Columns: [PRODUCAO, NATUREZA, TIPO-PRODUCAO, SEQUENCIA-PRODUCAO]
# Index: []

# %% [markdown]
# <div style="color:blue;" ><h2> Resumo da Orientações e Outras Produções </h2></div>

# %%
SUMARIO['RESUMOS'][6]
# Out:
#                         PRODUCAO                                  NATUREZA  \
# 0  OUTRAS-ORIENTACOES-CONCLUIDAS                      INICIACAO_CIENTIFICA
# 1  OUTRAS-ORIENTACOES-CONCLUIDAS  TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO
#
#      PAIS TIPO  SEQUENCIA-PRODUCAO
# 0  Brasil                        1
# 1  Brasil                        6

# %% [markdown]
# <div style="color:blue;" ><h2> Resumo de Dados Complementares </h2></div>

# %%
SUMARIO['RESUMOS'][7]
# Out:
#                                       PRODUCAO  \
# 0        BANCA-JULGADORA-PARA-CONCURSO-PUBLICO
# 1         ORIENTACAO-EM-ANDAMENTO-DE-GRADUACAO
# 2                     OUTRAS-BANCAS-JULGADORAS
# 3  PARTICIPACAO-EM-BANCA-DE-EXAME-QUALIFICACAO
# 4           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 5                    PARTICIPACAO-EM-CONGRESSO
# 6                     PARTICIPACAO-EM-ENCONTRO
# 7                     PARTICIPACAO-EM-SIMPOSIO
#
#                                       NATUREZA    PAIS  SEQUENCIA-PRODUCAO
# 0                             Concurso público  Brasil                   1
# 1  Trabalho de conclusão de curso de graduação  Brasil                   2
# 2                                        Outra  Brasil                   4
# 3            Exame de qualificação de mestrado  Brasil                   3
# 4                                    Graduação  Brasil                  13
# 5                                    Congresso  Brasil                   1
# 6                                     Encontro  Brasil                   1
# 7                                     Simpósio  Brasil                   1

# %% [markdown]
# <center><div style="color:#1A195C" ><h1> Listagem Geral de Produção no Período </h1></div></center>

# %% [markdown]
# <div style="color:#1A195C;" ><h2> Produção Bibliográfica </h2></div>

# %%
SUMARIO['PRODUCAO'][0]
# Out:
#       ANO SEQUENCIA-PRODUCAO             PRODUCAO  NATUREZA  \
# 46   2018                161  TRABALHO-EM-EVENTOS    RESUMO
# 47   2019                197  TRABALHO-EM-EVENTOS    RESUMO
# 49   2017                121     ARTIGO-PUBLICADO  COMPLETO
# 51   2019                160     ARTIGO-PUBLICADO  COMPLETO
# 100  2018                161  TRABALHO-EM-EVENTOS
# 101  2019                197  TRABALHO-EM-EVENTOS
#
#     CLASSIFICACAO-DO-EVENTO  \
# 46
# 47
# 49
# 51
# 100           INTERNACIONAL
# 101                NACIONAL
#
#                                         NOME-DO-EVENTO  \
# 46
# 47
# 49
# 51
# 100          13ª Congresso Internacional da Rede UNIDA
# 101  II Congresso Nacional de Práticas Integrativas...
#
#                                                 TITULO    PAIS  \
# 46   PRÁTICAS INTEGRATIVAS E COMPLEMENTARES GRUPAIS...  Brasil
# 47   PRÁTICAS INTEGRATIVAS E COMPLEMENTARES GRUPAIS...  Brasil
# 49   Práticas integrativas e complementares grupais...
# 51   A Psicologia no contexto das comunidades tradi...
# 100
# 101
#
#                                                REVISTA DOI   ISSN-ISBN QUALIS  \
# 46                                                            INVALIDO
# 47                                                            INVALIDO
# 49                                                            INVALIDO
# 51                                                            INVALIDO
# 100    Anais do 13º Congresso Internacional Rede Unida      2446--4813
# 101  II Congresso Nacional de Práticas Integrativas...        INVALIDO
#
#      flag_ISSN flag_Qualis
# 46        True
# 47        True
# 49        True
# 51        True
# 100       True
# 101       True

# %% [markdown]
# <div style="color:#1A195C;" ><h2> Produção Técnica - Apresentações </h2></div>

# %%
SUMARIO['PRODUCAO'][1]
# Out:
#      ANO SEQUENCIA-PRODUCAO                           PRODUCAO  \
# 6   2019                162           APRESENTACAO-DE-TRABALHO
# 7   2017                177           APRESENTACAO-DE-TRABALHO
# 8   2019                163           APRESENTACAO-DE-TRABALHO
# 9   2017                141  CURSO-DE-CURTA-DURACAO-MINISTRADO
# 10  2017                142  CURSO-DE-CURTA-DURACAO-MINISTRADO
# 11  2018                190  CURSO-DE-CURTA-DURACAO-MINISTRADO
# 39  2019                166            PROGRAMA-DE-RADIO-OU-TV
# 40  2019                187            PROGRAMA-DE-RADIO-OU-TV
# 41  2019                188            PROGRAMA-DE-RADIO-OU-TV
# 42  2017                178            PROGRAMA-DE-RADIO-OU-TV
# 43  2020                169              RELATORIO-DE-PESQUISA
# 44  2017                147             OUTRA-PRODUCAO-TECNICA
#
#                          NATUREZA  \
# 6                           OUTRA
# 7                     COMUNICACAO
# 8                     COMUNICACAO
# 9
# 10
# 11
# 39                   MESA_REDONDA
# 40                   MESA_REDONDA
# 41                   MESA_REDONDA
# 42                   MESA_REDONDA
# 43
# 44  Membro da Comissão Científica
#
#                                                TITULO     IDIOMA    PAIS DOI
# 6   Trabalho com Grupos na Estratégia de Saúde da ...  Português  Brasil
# 7   Práticas Integrativas e complementares grupais...  Português  Brasil
# 8   Interações Necessárias entre a Universidade- G...  Português  Brasil
# 9   Curso sobre Cuidados e Abordagens na Atenção P...  Português  Brasil
# 10  Metodologias Participativas para Intervenção I...  Português  Brasil
# 11  FORMAÇÃO EM PRÁTICAS INTEGRATIVAS E COMPLEMENT...  Português  Brasil
# 39  Objetivos, Atribuições e experiências em Educa...  Português  Brasil
# 40        Psicologia, Pics Grupais e Educação Popular  Português  Brasil
# 41  Contribuições da Psicologia na Consolidação da...  Português  Brasil
# 42  A atual efervescência da PNPICS: lugar e persp...  Português  Brasil
# 43  Práticas Integrativas e Complementares no Cont...  Português  Brasil
# 44  II Simpósio Paraibano de Práticas Integrativas...  Português  Brasil

# %% [markdown]
# <div style="color:#1A195C;" ><h2> Produção Técnica - Produtos e Processos </h2></div>

# %%
SUMARIO['PRODUCAO'][2]
# Out:
# Empty DataFrame
# Columns: [ANO, SEQUENCIA-PRODUCAO, PRODUCAO, NATUREZA, TIPO-PRODUCAO, TITULO]
# Index: []

# %% [markdown]
# <div style="color:#1A195C;" ><h2> Outras Produções </h2></div>

# %%
SUMARIO['PRODUCAO'][3]
# Out:
#      ANO SEQUENCIA-PRODUCAO                       PRODUCAO  \
# 6   2019                167  OUTRAS-ORIENTACOES-CONCLUIDAS
# 7   2019                179  OUTRAS-ORIENTACOES-CONCLUIDAS
# 8   2019                180  OUTRAS-ORIENTACOES-CONCLUIDAS
# 9   2018                181  OUTRAS-ORIENTACOES-CONCLUIDAS
# 10  2018                182  OUTRAS-ORIENTACOES-CONCLUIDAS
# 11  2018                183  OUTRAS-ORIENTACOES-CONCLUIDAS
# 12  2019                168  OUTRAS-ORIENTACOES-CONCLUIDAS
#
#                                     NATUREZA TIPO-DE-ORIENTACAO-CONCLUIDA  \
# 6   TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO
# 7                       INICIACAO_CIENTIFICA
# 8   TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO
# 9   TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO
# 10  TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO
# 11  TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO
# 12  TRABALHO_DE_CONCLUSAO_DE_CURSO_GRADUACAO
#
#                                                TITULO     IDIOMA    PAIS
# 6   Psicologia Comunitária e educação popular de m...  Português  Brasil
# 7   PRÁTICAS INTEGRATIVAS E COMPLEMENTARES NO CONT...  Português  Brasil
# 8   CIRANDA DAS ROSAS VERMELHAS APRISIONADAS: UM R...  Português  Brasil
# 9   MATRICIAMENTO EM SAÚDE MENTAL NO NASF: EXPERIÊ...  Português  Brasil
# 10  PRÁTICAS INTEGRATIVAS E COMPLEMENTARES GRUPAIS...  Português  Brasil
# 11  DÊ LICENÇA PRA MINHA HISTÓRIA CONTAR: NARRATIV...  Português  Brasil
# 12  Uma história que se faz no caminhar: o trabalh...  Português  Brasil

# %% [markdown]
# <div style="color:#1A195C;" ><h2> Informações Complementares </h2></div>

# %%
SUMARIO['PRODUCAO'][4]
# Out:
#      ANO SEQUENCIA-PRODUCAO                                     PRODUCAO  \
# 0   2019                184  PARTICIPACAO-EM-BANCA-DE-EXAME-QUALIFICACAO
# 1   2019                185  PARTICIPACAO-EM-BANCA-DE-EXAME-QUALIFICACAO
# 2   2018                186  PARTICIPACAO-EM-BANCA-DE-EXAME-QUALIFICACAO
# 12  2017                124           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 13  2017                125           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 14  2017                126           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 16  2020                164           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 17  2020                165           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 18  2020                170           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 19  2020                171           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 20  2020                172           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 21  2017                173           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 22  2017                174           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 23  2017                175           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 24  2017                176           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 25  2017                123           PARTICIPACAO-EM-BANCA-DE-GRADUACAO
# 30  2019                191        BANCA-JULGADORA-PARA-CONCURSO-PUBLICO
# 32  2017                157                     OUTRAS-BANCAS-JULGADORAS
# 33  2019                198                     OUTRAS-BANCAS-JULGADORAS
# 34  2019                199                     OUTRAS-BANCAS-JULGADORAS
# 35  2019                200                     OUTRAS-BANCAS-JULGADORAS
# 39  2018                189                    PARTICIPACAO-EM-CONGRESSO
# 43  2017                140                     PARTICIPACAO-EM-SIMPOSIO
# 48  2017                131                     PARTICIPACAO-EM-ENCONTRO
# 60  2018                128         ORIENTACAO-EM-ANDAMENTO-DE-GRADUACAO
# 61  2018                127         ORIENTACAO-EM-ANDAMENTO-DE-GRADUACAO
#
#                                        NATUREZA  \
# 0             Exame de qualificação de mestrado
# 1             Exame de qualificação de mestrado
# 2             Exame de qualificação de mestrado
# 12                                    Graduação
# 13                                    Graduação
# 14                                    Graduação
# 16                                    Graduação
# 17                                    Graduação
# 18                                    Graduação
# 19                                    Graduação
# 20                                    Graduação
# 21                                    Graduação
# 22                                    Graduação
# 23                                    Graduação
# 24                                    Graduação
# 25                                    Graduação
# 30                             Concurso público
# 32                                        Outra
# 33                                        Outra
# 34                                        Outra
# 35                                        Outra
# 39                                    Congresso
# 43                                     Simpósio
# 48                                     Encontro
# 60  Trabalho de conclusão de curso de graduação
# 61  Trabalho de conclusão de curso de graduação
#
#                                                TITULO     IDIOMA    PAIS DOI
# 0   Ações de atendimento às mulheres privadas de l...  Português  Brasil
# 1   Psicólogas (os) nos Núcleos de Apoio à Saúde d...  Português  Brasil
# 2   Psicólogos nos Núcleos de Apoio à Saúde da Fam...  Português  Brasil
# 12  Memórias em cor, voz e retalhos: tenda do cont...  Português  Brasil
# 13  A atuação do Psicólogo no Centro de Convivênci...  Português  Brasil
# 14  Programa Saúde na Escola: um relato de experiê...  Português  Brasil
# 16  Eu, Meu Filho e a Microcefalia: Representações...  Português  Brasil
# 17  Quando as Nuvens não Sinalizam Chuva: o pó e o...  Português  Brasil
# 18  Relatório PIBIC: Eu, meu filho e a microcefali...  Português  Brasil
# 19  A influência dos contos de fada na construção ...  Português  Brasil
# 20  Representações sociais sobre o feminicídio na ...  Português  Brasil
# 21  Programa Saúde na Escola: u relato de experiên...  Português  Brasil
# 22  Afetos e significações evocados pelo exame cit...  Português  Brasil
# 23  A atuação do psicólogo no centro de convivênci...  Português  Brasil
# 24  Memórias em cor, voz e retalhos da tenda do co...  Português  Brasil
# 25  Afetos e significações evocados pelo exame cit...  Português  Brasil
# 30                                         Psicologia  Português  Brasil
# 32  Membro Titular da Comissão Avaliadora do Proce...  Português  Brasil
# 33  Avaliação de Relatório Parcial PIBIC/UFCG: Rep...  Português  Brasil
# 34  Avaliação de Relatório Parcial PIBIC/UFCG; Eu,...  Português  Brasil
# 35  Avaliação de Relatório Parcial PIBIC/UFCG: A i...  Português  Brasil
# 39  Práticas Integrativas e Complementares Grupais...             Brasil
# 43  A atual efervescência da PNPICS: lugar e persp...             Brasil
# 48  Práticas Integrativas e Complementares Grupais...             Brasil
# 60  Metodologias participativas na formação de age...  Português  Brasil
# 61  Práticas Integrativas e Complementares no sist...  Português  Brasil

# %% [markdown]
# # Pontuação do Currículo antes de Normalização

# %%
PQ.doPontuacao(save_to_disk = True)[['AREA', 'ID','CPF', 'NOME', 'DOUTORADO', 'Nota_CVP']]
# Out:
#          AREA                ID          CPF  \
# 0  PSICOLOGIA  6832534027323796  51145669468
#
#                                      NOME  DOUTORADO  Nota_CVP
# 0  Maria Valquíria Nogueira do Nascimento       2016      15.5

# %% [markdown]
# # Critérios de Pontuação

# %%
pontuacao = pd.read_excel('../data/pontuacao.xlsx')
pontuacao.fillna('')
# Out:
#            LATTES                               PRODUCAO  \
# 0   BIBLIOGRAFICA                       ARTIGO-PUBLICADO
# 1   BIBLIOGRAFICA                       ARTIGO-PUBLICADO
# 2   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 3   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 4   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 5   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 6   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 7   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 8   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 9   BIBLIOGRAFICA           OUTRA-PRODUCAO-BIBLIOGRAFICA
# 10  BIBLIOGRAFICA             TEXTO-EM-JORNAL-OU-REVISTA
# 11  BIBLIOGRAFICA                    TRABALHO-EM-EVENTOS
# 12  BIBLIOGRAFICA                    TRABALHO-EM-EVENTOS
# 13  BIBLIOGRAFICA                    TRABALHO-EM-EVENTOS
# 14  BIBLIOGRAFICA                    TRABALHO-EM-EVENTOS
# 15        TECNICA                                  MARCA
# 16        TECNICA                                PATENTE
# 17        TECNICA                  PROCESSOS-OU-TECNICAS
# 18        TECNICA                    PRODUTO-TECNOLOGICO
# 19        TECNICA                               SOFTWARE
# 20         OUTRAS                          ARTES-CENICAS
# 21         OUTRAS                          ARTES-VISUAIS
# 22         OUTRAS                          ARTES-VISUAIS
# 23         OUTRAS                          ARTES-VISUAIS
# 24         OUTRAS                                 MUSICA
# 25         OUTRAS  ORIENTACOES-CONCLUIDAS-PARA-DOUTORADO
# 26         OUTRAS   ORIENTACOES-CONCLUIDAS-PARA-MESTRADO
# 27         OUTRAS      OUTRA-PRODUCAO-ARTISTICA-CULTURAL
# 28         OUTRAS      OUTRA-PRODUCAO-ARTISTICA-CULTURAL
# 29         OUTRAS          OUTRAS-ORIENTACOES-CONCLUIDAS
#
#                    NATUREZA  flag_Nacional  PONTOS  MAX
# 0                  COMPLETO  Internacional     3.5
# 1                  COMPLETO       Nacional     2.5
# 2         Capítulo de Livro       Nacional     2.5
# 3     Divulgação Científica       Nacional     0.1    2
# 4     Divulgação Científica  Internacional     0.1    2
# 5      Publicação de resumo       Nacional     0.2
# 6          Resumo Expandido       Nacional     0.5
# 7         Resumo em revista       Nacional     0.1
# 8                   Revista       Nacional     0.1    2
# 9      preprinte eletrônico       Nacional     0.1    2
# 10       JORNAL_DE_NOTICIAS       Nacional     0.1    2
# 11                 COMPLETO  Internacional     1.5  7.5
# 12                 COMPLETO       Nacional     1.0    5
# 13                   RESUMO                    0.2    1
# 14         RESUMO_EXPANDIDO                    0.5  2.5
# 15                                             2.0
# 16                                             2.0
# 17                ANALITICA                    2.0
# 18                 APARELHO                    2.0
# 19            NAO_INFORMADO                    2.0
# 20                  TEATRAL                    4.0
# 21                    FILME                    4.0
# 22                    OUTRA                    4.0
# 23                    VIDEO                    4.0
# 24                 DIVERSAS                    4.0
# 25        Tese de doutorado                    4.0
# 26  Dissertação de mestrado                    2.5
# 27    Exposição de Maquetes                    0.5    2
# 28       Vídeo documentário                    2.5
# 29     INICIACAO_CIENTIFICA                    1.0   16
